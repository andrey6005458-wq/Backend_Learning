# %% [markdown]
# # Шаблоны Markdown

# %% [markdown]
# ## Заголовок 2

# %% [markdown]
# ### Заголовок 3

# %% [markdown]
# ## Форматирование

# %% [markdown]
# **bold** normal

# %% [markdown]
# *italic*

# %% [markdown]
# `моноширинный`

# %% [markdown]
# <ins>text</ins>

# %% [markdown]
# ## Списки

# %% [markdown]
# - apple
# - pineapple
# - peach

# %% [markdown]
# 1. milk
# 2. bread
# 3. eggs

# %% [markdown]
# текст<br>текст<br>текст

# %% [markdown]
# # Ссылки

# %% [markdown]
# [`GitHub`](https://github.com/andrey6005458-wq)
